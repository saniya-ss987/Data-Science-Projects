# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Saniya Shakil Shaikh**
#
#  Aspiring Data Scientist

# %% [markdown]
# *I am interested in Data Science because it is an intersection of my top favoutite subjects like mathematics, statistics, computer science and business studies. Also, it provides me an exciting career path in multiple industries such as Healthcare, Security,
# E-commerce, Security, etc.*

# %% [markdown]
# ### Here we've used logical operator 'and' that returns True if both the statements are true.

# %%
a = 50
b = 10
c = 20
d = 2
a > b and c > d
# Out:
# True

# %% [markdown]
# **TABLE**
#
# Alphabets| Numbers |Symbols
#  ---|---|---
#  a  | 1 | @
#  b  | 2 | #
#  c  | 3 | %
#  d  | 4 | &
#  e  | 5 | !
# ---
# #Bulleted Lists
#  * Item A
#  * Item B
#  * Item C
# ---
# #Numbered Lists
#  1. Square
#  2. Rectangle
#  3. Rhombus
#  4. Parallelogram
